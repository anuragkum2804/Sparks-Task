# %% [markdown]
# ## Task 4
# ## Author: Anurag Kumar

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import chardet
with open(r"C:\Users\ARUN KUMAR\Desktop\Global_Terrorism.csv",'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df = pd.read_csv(r"C:\Users\ARUN KUMAR\Desktop\Global_Terrorism.csv",encoding = 'ISO-8859-1')
# Out:
# C:\Users\ARUN KUMAR\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.set_option('display.max_columns',None)
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
pd.set_option('display.max_rows',None)
df.isna().sum()
# Out:
# eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            172452
# extended                   0
# resolution            179471
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate                421
# city                     434
# latitude                4556
# longitude               4557
# specificity                6
# vicinity                   0
# location              126196
# summary                66129
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           152680
# alternative_txt       152680
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
# attacktype2           175377
# attacktype2_txt       175377
# ...

# %%
df= df[df['longitude']!=df.longitude.min()]
df.shape
# Out:
# (181690, 135)

# %%
Y=df.groupby('region_txt').count().sort_values('extended',ascending=False)['extended']

# %% [markdown]
# ##### Middle East& North Africa has the most terrorist attacks

# %%
Y.plot.bar()
# Out:
# <AxesSubplot:xlabel='region_txt'>

# %%
Z=df[df.region==10].groupby('country_txt').count().sort_values('extended',ascending=False)['extended']

# %%
Z.plot.bar()
# Out:
# <AxesSubplot:xlabel='country_txt'>

# %% [markdown]
# ##### Iraq has the most terrorist attacks in middle east

# %%
Z=df[df['region_txt']=='South Asia'].groupby('country_txt').count().sort_values('extended',ascending=False)['extended']
Z.plot.bar()
# Out:
# <AxesSubplot:xlabel='country_txt'>

# %% [markdown]
# #### Pakistan, Afghanistan and India are in the Top 3 in South Asia

# %% [markdown]
# ### Top 10 countries in the world

# %%
Z=df.groupby('country_txt').count().sort_values('extended',ascending=False).head(10)['extended']
Z.plot.bar()
# Out:
# <AxesSubplot:xlabel='country_txt'>

# %%
X = df[df['iyear']>=2000]
X.shape[0]
X.shape[0]/df.shape[0]*100
# Out:
# 61.563652374924324

# %%
X.head()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 69835  200001010001   2000       1     1        NaN         0        NaN
# 69836  200001010002   2000       1     1        NaN         1        NaN
# 69837  200001010003   2000       1     1        NaN         0        NaN
# 69838  200001010004   2000       1     1        NaN         0        NaN
# 69839  200001010005   2000       1     1        NaN         0        NaN
#
#        country country_txt  region          region_txt          provstate  \
# 69835      139     Namibia      11  Sub-Saharan Africa            Kavango
# 69836      139     Namibia      11  Sub-Saharan Africa            Kavango
# 69837       92       India       6          South Asia  Jammu and Kashmir
# 69838     1003      Kosovo       9      Eastern Europe  Kosovo (Province)
# 69839      182     Somalia      11  Sub-Saharan Africa           Banaadir
#
#             city   latitude  longitude  specificity  vicinity  \
# ...

# %%
X=X.groupby('region_txt').count().sort_values('extended',ascending=False)['extended']
X.plot.bar()
# Out:
# <AxesSubplot:xlabel='region_txt'>

# %% [markdown]
# #### Graph of percentage of terrorist attacks after 2000 compared to total terrorist attacks

# %%
(X/Y*100).plot.bar()
# Out:
# <AxesSubplot:xlabel='region_txt'>

# %% [markdown]
# #### In Eastern Europe, Middle East, South asia, Southeast Asia and subsaharan Africa there has been a huge increase in terrorist attacks whereas other regions have seen a decrease since 2000

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
df.plot(kind="scatter", x="longitude", y="latitude")
plt.ticklabel_format(style='plain')
plt.show()

# %% [markdown]
# #### Number of people Killed and wounded region wise

# %%
A=df.groupby('region_txt').sum().sort_values(by='nkill',ascending=False)['nkill']
A.plot.bar()
# Out:
# <AxesSubplot:xlabel='region_txt'>

# %%
A=df.groupby('region_txt').sum().sort_values(by='nwound',ascending=False)['nwound']
A.plot.bar()
# Out:
# <AxesSubplot:xlabel='region_txt'>

# %% [markdown]
# #### Top 10 countries in number of people killed and wounded in Terrorist attacks

# %%
Z=df.groupby('country_txt').sum().sort_values('nkill',ascending=False).head(10)['nkill']
Z.plot.bar()
# Out:
# <AxesSubplot:xlabel='country_txt'>

# %%
Z=df.groupby('country_txt').sum().sort_values('nwound',ascending=False).head(10)['nwound']
Z.plot.bar()
# Out:
# <AxesSubplot:xlabel='country_txt'>
